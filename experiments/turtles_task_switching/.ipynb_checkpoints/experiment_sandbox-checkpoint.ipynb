# %%
import numpy as np
import pandas as pd
s=pd.read_csv("stim/stim_transfer_switch.csv")
#standard=s[s["trial_type"]=="standard"]
#switch=s[s["trial_type"]=="switch"]
#n_standard=standard.shape[0]
#n_switch=switch.shape[0]
#n_total=s.shape[0]
#print(standard)
do_sample = True

#print(s)
print(s.iloc[2-1]["trial_type"])
while do_sample:
    s = s.sample(frac=1).reset_index(drop=True)
    X=0
    for i in range(2,s.shape[0]-1):
        if s.iloc[i]["trial_type"]=='switch':
            if s.iloc[i-1]["trial_type"]=='switch':
                X=X+1
    if(X==0):
        do_sample=False
    
#    do_sample=False
print(s)

# %%
def randomize_switch_trials(trials, standard, switch):
    do_random=True
    x=1
    
    while do_random:
        #print(x)
        order=np.concatenate((np.repeat(0,n_standard-1),
                              np.repeat(1,n_switch))) 
        np.random.shuffle(order) # shuffle order around
        shuffled_tmp=np.concatenate((np.array([0]),order)) # ensure that block starts with a standard trial
        shuffled_tmp_cumsum=np.cumsum(shuffled_tmp,axis=0) # cumulative sum of ordering
        x=x+1
        #print(shuffled_tmp)
        check=np.empty([n_total-2])
        #print(check)
        for i in range(2,n_total-2):
            #print(i)
            check[i]=(shuffled_tmp_cumsum[i]>shuffled_tmp_cumsum[i-1]) & (shuffled_tmp_cumsum[i-1]>shuffled_tmp_cumsum[i-2])
        if(sum(check)==0):
            do_random=False
            shuffled=shuffled_tmp
            #print(x)
            #print(order)
        #return shuffled_tmp
    reg=np.where(shuffled==0)
    sw=np.where(shuffled==1)
    standard=standard.sample(frac=1).reset_index(drop=True)
    switch=switch.sample(frac=1).reset_index(drop=True)
    standard_current_index=1
    switch_current_index=1
    trials_shuffled=pd.DataFrame(columns=['stim','category','angle_psy','radius_psy','angle','radius','trial_type'])
    for i in range(0,n_total-1):
        if(shuffled[i]==0):
            #print(standard.iloc[standard_current_index])
            trials_shuffled.append(standard.iloc[standard_current_index])
            standard_current_index=standard_current_index+1
        elif(shuffled[i]==1):
            #trials_shuffled=pd.concat([trials_shuffled,switch.iloc[switch_current_index]])
            #print(switch.iloc[switch_current_index])
            trials_shuffled.append(switch.iloc[switch_current_index])
            switch_current_index=switch_current_index+1
    return trials_shuffled

x=randomize_switch_trials(n_standard,n_switch,standard,switch)
print(x)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/qt/2jlz1bcx2515z3bzk5r90mw00000gn/T/ipykernel_6603/1159705791.py in <module>
#      41     return trials_shuffled
#      42
# ---> 43 x=randomize_switch_trials(n_standard,n_switch,standard,switch)
#      44 print(x)
#
# /var/folders/qt/2jlz1bcx2515z3bzk5r90mw00000gn/T/ipykernel_6603/1159705791.py in randomize_switch_trials(n_standard, n_switch, standard, switch)
#      32         if(shuffled[i]==0):
#      33             #print(standard.iloc[standard_current_index])
# ---> 34             trials_shuffled.append(standard.iloc[standard_current_index])
#      35             standard_current_index=standard_current_index+1
#      36         elif(shuffled[i]==1):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/indexing.py in __getitem__(self, key)
# ...
