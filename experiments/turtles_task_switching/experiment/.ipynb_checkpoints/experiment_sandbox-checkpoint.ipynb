# %%
import pandas as pd
import numpy as np
avg_turtle=pd.read_csv("stim/stim_avg_turtle.csv")
# print(avg_turtle)
avg_turtle_radius=avg_turtle['radius'][0]
print(avg_turtle_radius)
# Out:
# 85
